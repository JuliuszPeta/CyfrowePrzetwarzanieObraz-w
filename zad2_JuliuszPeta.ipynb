# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

def load_image(filename):
  im = np.array(Image.open('zad2_1.jpg')).mean(axis=2)/255
  return im

def draw_image(im):
  plt.figure(figsize=(12,9))
  plt.imshow(im, cmap='gray')
  plt.clim(0, 1)
  plt.colorbar()

im = load_image('zad2_1.jpg')
plt.imshow(im, cmap='gray')
plt.clim(0, 1)
plt.colorbar()
plt.show()

#konwersja do skali szarości
im_gray = np.mean(im, axis = 2)/255.0

#zwiększenie kontrastu
contrast = im_gray * 1.4
plt.subplot(1,2,2)
plt.imshow(constrast, cmap='gray')
plt.clim(0, 1)
plt.colorbar()
plt.title('Poprawiony kontrast')

#Korekcja gamma
gamma = im_gray**0.6

plt.figure(figsize=(12, 6))

plt.subplot(1,2,2)
plt.imshow(gamma, cmap='gray')
plt.clim(0, 1)
plt.colorbar()
plt.title('Poprawione wartości gamma')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-dd28bdae6cde> in <module>
#      20
#      21 #konwersja do skali szarości
# ---> 22 im_gray = np.mean(im, axis = 2)/255.0
#      23
#      24 #zwiększenie kontrastu
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3332             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3333
# -> 3334     return _methods._mean(a, axis=axis, dtype=dtype,
#    3335                           out=out, **kwargs)
#    3336
#
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#     136
#     137     is_float16_result = False
# --> 138     rcount = _count_reduce_items(arr, axis)
#     139     # Make this warning show up first
#     140     if rcount == 0:
#
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _count_reduce_items(arr, axis)
#      55     items = 1
#      56     for ax in axis:
# ---> 57         items *= arr.shape[ax]
#      58     return items
#      59
#
# IndexError: tuple index out of range
